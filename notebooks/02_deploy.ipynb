# %% [markdown]
# ## SageMaker Endpoint Deployment
#
# This notebook was developed and run inside AWS SageMaker Studio. It is included here for reference. It is not intended to be run locally.
#
# **What it does:**
# 1. Deploys DistilBERT as a live SageMaker real-time endpoint
# 2. Tests the endpoint with a sample prediction
# 3. Deletes the endpoint to stop incurring charges

# %%
exec(open("../sagemaker/deploy_endpoint.py").read())
